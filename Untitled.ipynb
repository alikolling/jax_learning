# %%
import jax.numpy as jnp
from jax import grad, jit, vmap
from jax import random

# %%
key = random.PRNGKey(1)
x = random.normal(key, (10,))
print(x)
# Out:
# 2022-11-28 15:09:43.144122: E external/org_tensorflow/tensorflow/compiler/xla/pjrt/pjrt_stream_executor_client.cc:2153] Execution of replica 0 failed: INTERNAL: CustomCall failed: jaxlib/gpu/prng_kernels.cc:33: operation gpuGetLastError() failed: no kernel image is available for execution on the device
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# /tmp/ipykernel_116227/4127595137.py in <module>
#       1 key = random.PRNGKey(1)
# ----> 2 x = random.normal(key, (10,))
#       3 print(x)
#
# ~/.local/lib/python3.10/site-packages/jax/_src/random.py in normal(key, shape, dtype)
#     559   dtype = dtypes.canonicalize_dtype(dtype)
#     560   shape = core.as_named_shape(shape)
# --> 561   return _normal(key, shape, dtype)  # type: ignore
#     562
#     563 @partial(jit, static_argnums=(1, 2), inline=True)
#
#     [... skipping hidden 2 frame]
#
# ~/.local/lib/python3.10/site-packages/jax/_src/dispatch.py in _execute_compiled(name, compiled, input_handler, output_buffer_counts, result_handler, has_unordered_effects, ordered_effects, kept_var_idx, has_host_callbacks, *args)
#     893       runtime_token = None
#     894   else:
# --> 895     out_flat = compiled.execute(in_flat)
#     896   check_special(name, out_flat)
#     897   out_bufs = unflatten(out_flat, output_buffer_counts)
#
# XlaRuntimeError: INTERNAL: CustomCall failed: jaxlib/gpu/prng_kernels.cc:33: operation gpuGetLastError() failed: no kernel image is available for execution on the device
